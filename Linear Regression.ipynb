# %% [markdown]
# # Linear Regression Algorithm

# %% [markdown]
# ## Agenda for Today's Session
#
# - What is Regression?
# - Regression Use-case
# - Types of Regression - Linear vs Logistic Regression
# - What is Linear Regression?
# - Fiding best fit regression line usin Least Square Method
# - Checking goodness of fit using R squared Method
# - Implementation of Linear Regression using Python
# - Implementation of Linear Regression using Python
#     * Linear Regression Algorithm using Python from scratch
#     * Linear Regression Algorithm using Python (scikit lib)

# %% [markdown]
# ### What is **Regression**?
#     - Regression is analysis is a form of predictive modelling technique which investigates the relationship between a dependent and independent variable

# %% [markdown]
# ### Uses of Regression
#    - Three major uses for regression analysis are
#         * Determining the strength of predictors
#         * Forecasting an effect, and
#         * Trend forecasting

# %% [markdown]
# ### Linear vs Logistic Regression
#
# |Basis|Linear Regression|Logistic Regression|
# |-----|-----------------|-------------------|
# |**Core Concept**|The data is modelled using a straight line|The probability of some obtained event is represented as a linear function of a combination of predictor variables|
# |**Used with**|Continous Variables|Categorical Variable|
# |**Output/Prediction**|value of the variable| Probability of occurence of event|
# |**Accuracy and Goodnees of fit**|measured by loss, R squared, Adjusted R squared etc.| Accuracy, Precision, Recall, F1 score, ROC curve, Confusion Matrix, etc.|

# %% [markdown]
# ### Linear Regression Selection Criteria
# - Classification and Regression
# - Data Quality
# - Computation Complexity
# - Comprehensible and Transparent
#
# ### Where is Linear Regression used?
# - Evaluation Trend and Sales Estimates
# - Analyzin the Impact of Price Changes
# - Assessment of risk in financial services and insurance domain
#
# ### Understanding Linear Regression Algorithm
#
# |x|y|x-x'|y-y'|(x-x')ˆ2|(x-x')(y-y')|
# |-|-|----|----|--------|------------|
# |1|3|1-3|3-3.6|4|1.2|
# |2|4|2-3|4-3.6|1|-0.4|
# |3|2|3-3|2-3.6|0|0|
# |4|4|4-3|4-3.6|1|0.4|
# |5|5|5-3|5-3.6|4|2.8|

# %% [markdown]
# ## Let's Learn to code

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

#Reding Data
data = pd.read_csv('headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
#so we can find a linear and chip between the head size
#and the Brain weights.
X = data['Head Size(cm^3)'].values
Y = data['Brain Weight(grams)'].values

# %%
# Mean X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

#Total number of values
m = len(X)

#using the formula to calculate b1 and b2
number = 0
denom = 0
for i in range(m):
    number += (X[i]-mean_x)*(Y[i] - mean_y)
    denom += (X[i]-mean_x)**2

b1 = number/denom
b0 = mean_y - (b1 * mean_x)

#Print coefficients
print(b1, b0)
# Out:
# 0.26342933948939945 325.57342104944223

# %%
#Ploting values and Regression line
max_x = np.max(X)+100
min_x = np.min(X)-100

#Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

#Ploting line
plt.plot(x, y, color='#58b970', label= 'Regression')
#Ploting Scatter Points
plt.scatter(X, Y, c='#ef5423', label= 'Scatter Plot')

plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.show()

# %%
ss_t = 0
ss_r = 0

for i in range(m):
    y_pred = b0 + b1*X[i]
    ss_t += (Y[i] - mean_y) ** 2
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.6393117199570003

# %% [markdown]
# ## Using SkLearn Library

# %% [markdown]
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error
#
# #Cannot use Rank 1 matrix in scikit learn
# X = X.reshape(m, 1)
#
# #Creating Model
# reg = LinearRegression()
#
# #Y prediction
# y_pred = reg.predict(X)
#
# #Calculating RMS and R2 Score
# mse = mean_squared_error(Y, Y_pred)
# rmse = np.sqrt(mse)
# r2_score = reg.score(X, y)
#
# print(np.sqrt(mse))
# print(r2_score)

# %% [markdown]
# # Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 5     7.4;0.66;0;1.8;0.075;13;40;0.9978;3.51;0.56;9.4;5
# 6     7.9;0.6;0.06;1.6;0.069;15;59;0.9964;3.3;0.46;9...
# 7      7.3;0.65;0;1.2;0.065;15;21;0.9946;3.39;0.47;10;7
# 8     7.8;0.58;0.02;2;0.073;9;18;0.9968;3.36;0.57;9.5;7
# 9     7.5;0.5;0.36;6.1;0.071;17;102;0.9978;3.35;0.8;...
# 10    6.7;0.58;0.08;1.8;0.097;15;65;0.9959;3.28;0.54...
# 11    7.5;0.5;0.36;6.1;0.071;17;102;0.9978;3.35;0.8;...
# 12    5.6;0.615;0;1.6;0.089;16;59;0.9943;3.58;0.52;9...
# 13    7.8;0.61;0.29;1.6;0.114;9;29;0.9974;3.26;1.56;...
# ...

# %% [markdown]
# ## Pre-processing

# %%
file = open("winequality-red.csv", "r")
for line in file:
    print(line)
# Out:
# "fixed acidity";"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
#
# 7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
#
# 7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
#
# 7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;9.8;5
#
# 11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58;9.8;6
#
# 7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
#
# 7.4;0.66;0;1.8;0.075;13;40;0.9978;3.51;0.56;9.4;5
#
# 7.9;0.6;0.06;1.6;0.069;15;59;0.9964;3.3;0.46;9.4;5
#
# 7.3;0.65;0;1.2;0.065;15;21;0.9946;3.39;0.47;10;7
#
# 7.8;0.58;0.02;2;0.073;9;18;0.9968;3.36;0.57;9.5;7
#
# 7.5;0.5;0.36;6.1;0.071;17;102;0.9978;3.35;0.8;10.5;5
#
# 6.7;0.58;0.08;1.8;0.097;15;65;0.9959;3.28;0.54;9.2;5
#
# 7.5;0.5;0.36;6.1;0.071;17;102;0.9978;3.35;0.8;10.5;5
#
# 5.6;0.615;0;1.6;0.089;16;59;0.9943;3.58;0.52;9.9;5
#
# 7.8;0.61;0.29;1.6;0.114;9;29;0.9974;3.26;1.56;9.1;5
#
# 8.9;0.62;0.18;3.8;0.176;52;145;0.9986;3.16;0.88;9.2;5
# ...

# %%
file = open("winequality-red.csv", "r")
names = []
fixed = []
volatile = []
citric = []
residual = []
chlorides = []
dioxide = []
total_dioxide = []
density = []
ph = []
sulphates = []
alcohol = []
quality = []

i = 0

# read line to line of line's file

for line in file:
    i += 1
    if i == 1:
        s = line.split(";")
        s
        for j in range(len(s)):
            names.append(s[j])
    else:
        s = line.split(";")
        fixed.append(float(s[0]))
        volatile.append(float(s[1]))
        citric.append(float(s[2]))
        residual.append(float(s[3]))
        chlorides.append(float(s[4]))
        dioxide.append(float(s[5]))
        total_dioxide.append(float(s[6]))
        density.append(float(s[7]))
        ph.append(float(s[8]))
        sulphates.append(float(s[9]))
        alcohol.append(float(s[10]))
        quality.append(float(s[11]))
            
    # print(line)
print(names)
print(fixed[0])
print(volatile[0])
print(citric[0])
print(residual[0])
print(chlorides[0])
print(dioxide[0])
print(total_dioxide[0])
print(density[0])
print(ph[0])
print(sulphates[0])
print(alcohol[0])
print(quality[0])
# Out:
# ['"fixed acidity"', '"volatile acidity"', '"citric acid"', '"residual sugar"', '"chlorides"', '"free sulfur dioxide"', '"total sulfur dioxide"', '"density"', '"pH"', '"sulphates"', '"alcohol"', '"quality"\n']
# 7.4
# 0.7
# 0.0
# 1.9
# 0.076
# 11.0
# 34.0
# 0.9978
# 3.51
# 0.56
# 9.4
# 5.0

# %%
datas = []
for i in range(len(fixed)):
    datas.append([fixed[i], volatile[i], citric[i], residual[i], 
                 chlorides[i], dioxide[i], total_dioxide[i], density[i], ph[i], 
                 sulphates[i], alcohol[i], quality[i]])

datas = np.asarray(datas)
names = np.asarray(names)
print(datas.shape)
print(names[8])
print(datas[1:1599][7])
# Out:
# (1599, 12)
# "pH"
# [ 7.8     0.58    0.02    2.      0.073   9.     18.      0.9968  3.36
#   0.57    9.5     7.    ]

# %%
#d = {names[0]: datas[0:1599][0], names[1]: datas[0:1599][1], names[2]: datas[0:1599][2], names[3]: datas[0:1599][3],
#    names[4]: datas[0:1599][4], names[5]: datas[0:1599][5], names[6]: datas[0:1599][6], names[7]: datas[0:1599][7],
#    names[8]: datas[0:1599][8], names[9]: datas[0:1599][9], names[10]: datas[0:1599][10], names[11]: datas[0:1599][11]} 
df = pd.DataFrame(datas, columns = names)

# %%
df.head()
# Out:
#    "fixed acidity"  "volatile acidity"  "citric acid"  "residual sugar"  \
# 0              7.4                0.70           0.00               1.9
# 1              7.8                0.88           0.00               2.6
# 2              7.8                0.76           0.04               2.3
# 3             11.2                0.28           0.56               1.9
# 4              7.4                0.70           0.00               1.9
#
#    "chlorides"  "free sulfur dioxide"  "total sulfur dioxide"  "density"  \
# 0        0.076                   11.0                    34.0     0.9978
# 1        0.098                   25.0                    67.0     0.9968
# 2        0.092                   15.0                    54.0     0.9970
# 3        0.075                   17.0                    60.0     0.9980
# 4        0.076                   11.0                    34.0     0.9978
#
#    "pH"  "sulphates"  "alcohol"  "quality"\n
# 0  3.51         0.56        9.4          5.0
# ...

# %%
df.to_csv(r'wine-quality.csv')

# %% [markdown]
# ## Linear Regression Multiple Variables

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
df = pd.read_csv('wine-quality.csv', names=["Id","Fixed Acidity","Volatile Acidity","Citric Acid","Residual Sugar","Chlorides","Free sulfur dioxide","Total Sulfur Dioxide","Density","pH","Sulphates","Alcohol","Quality"], header=0)
df.head()
# Out:
#    Id  Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  \
# 0   0            7.4              0.70         0.00             1.9
# 1   1            7.8              0.88         0.00             2.6
# 2   2            7.8              0.76         0.04             2.3
# 3   3           11.2              0.28         0.56             1.9
# 4   4            7.4              0.70         0.00             1.9
#
#    Chlorides  Free sulfur dioxide  Total Sulfur Dioxide  Density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    Sulphates  Alcohol  Quality
# 0       0.56      9.4      5.0
# 1       0.68      9.8      5.0
# 2       0.65      9.8      5.0
# ...

# %%
df.drop("Id", axis=1, inplace=True)
df.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    Free sulfur dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    Alcohol  Quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
X, y = df.drop('Quality',axis=1),df['Quality']
X.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    Free sulfur dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    Alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %% [markdown]
# ## Train & Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Create to class object

# %%
reg = linear_model.LinearRegression()
##Using your training set
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([ 2.34704718e-02, -1.09961969e+00, -2.47859776e-01,  7.73785620e-03,
#        -1.67359251e+00,  4.55041815e-03, -3.26389168e-03, -1.42395563e+01,
#        -3.19247444e-01,  8.12824701e-01,  2.91991158e-01])

# %%
reg.intercept_
# Out:
# 17.962578339234504

# %%
predict = reg.predict(X_test)

# %% [markdown]
# ### Metrics & Evaluated the Model

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_squared_error

r2 = r2_score(y_test, predict)
mae = median_absolute_error(y_test, predict)
mse = mean_squared_error(y_test, predict)
#print("MSE \t MAE \t R2")
print("MSE: "+str(mse)+"\tMAE: "+str(mae)+"\tR2: "+str(r2))
# Out:
# MSE: 0.4112348717504198	MAE: 0.4212715156569633	R2: 0.3513885332505239

# %% [markdown]
# ### Implemeting Scatter

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

N = y_test.shape
x = predict
y = y_test
colors = y_test
#area = np.pi * (10 * np.random.rand(162))**2  # 0 to 15 point radii
area = 80
#plt.title("\nXception\n", fontsize=18)
plt.xlabel("\nPredicted\n", fontsize=12)
plt.ylabel("\nGround Truth\n", fontsize=12)
marker_size=15
#plasma viridis hot
plt.scatter(x, y, s=area, c=colors, cmap='cool', alpha=0.5)
#plt.gca().set_axis_bgcolor('white')

cbar= plt.colorbar()
cbar.set_label("Quality Grade", labelpad=+1)
figure(figsize=(10,5))
plt.show()
